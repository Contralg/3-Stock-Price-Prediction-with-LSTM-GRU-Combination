# %% [markdown]
# # Preprocessing

# %%
#Import Library yang diperlukan

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import sys
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, TensorDataset

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %%
#Import dataset

datapath = '../../../1. Data/Raw/Data Historis PGAS.csv'
dataset = pd.read_csv(datapath)
dataset
# Out:
#          Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah      Vol Perubahan%
# 0     01/03/2024      1105       1090       1110      1090   53,60M      1,38%
# 1     29/02/2024      1090       1115       1115      1090  132,02M     -2,24%
# 2     28/02/2024      1115       1125       1125      1105   75,90M     -0,89%
# 3     27/02/2024      1125       1140       1140      1120   71,32M     -0,88%
# 4     26/02/2024      1135       1160       1160      1130   67,38M     -2,16%
# ...          ...       ...        ...        ...       ...      ...        ...
# 2426  07/03/2014      4960       5025       5050      4960    9,67M     -0,80%
# 2427  06/03/2014      5000       5050       5075      5000   12,10M      0,00%
# 2428  05/03/2014      5000       4955       5075      4945   23,96M      1,11%
# 2429  04/03/2014      4945       4910       4945      4910   12,32M      0,10%
# 2430  03/03/2014      4940       4900       4945      4885   11,51M      0,82%
#
# [2431 rows x 7 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2431 entries, 0 to 2430
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     2431 non-null   object
#  1   Terakhir    2431 non-null   int64
#  2   Pembukaan   2431 non-null   int64
#  3   Tertinggi   2431 non-null   int64
#  4   Terendah    2431 non-null   int64
#  5   Vol         2431 non-null   object
#  6   Perubahan%  2431 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 133.1+ KB

# %%
dataset.describe()
# Out:
#           Terakhir    Pembukaan    Tertinggi     Terendah
# count  2431.000000  2431.000000  2431.000000  2431.000000
# mean   2357.130810  2362.379679  2397.130810  2325.318799
# std    1334.055748  1335.914032  1345.166329  1321.762016
# min     605.000000   610.000000   680.000000   605.000000
# 25%    1425.000000  1422.500000  1450.000000  1400.000000
# 50%    1990.000000  1990.000000  2030.000000  1965.000000
# 75%    2615.000000  2625.000000  2665.000000  2585.000000
# max    6175.000000  6225.000000  6225.000000  6150.000000

# %%
dataset.isna().sum().to_frame(name='num_of_NaN')
# Out:
#             num_of_NaN
# Tanggal              0
# Terakhir             0
# Pembukaan            0
# Tertinggi            0
# Terendah             0
# Vol                  0
# Perubahan%           0

# %%
from datetime import datetime
dataset['Tanggal'] = pd.to_datetime(dataset['Tanggal'],
                                   format = '%d/%m/%Y')
dataset
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah      Vol Perubahan%
# 0    2024-03-01      1105       1090       1110      1090   53,60M      1,38%
# 1    2024-02-29      1090       1115       1115      1090  132,02M     -2,24%
# 2    2024-02-28      1115       1125       1125      1105   75,90M     -0,89%
# 3    2024-02-27      1125       1140       1140      1120   71,32M     -0,88%
# 4    2024-02-26      1135       1160       1160      1130   67,38M     -2,16%
# ...         ...       ...        ...        ...       ...      ...        ...
# 2426 2014-03-07      4960       5025       5050      4960    9,67M     -0,80%
# 2427 2014-03-06      5000       5050       5075      5000   12,10M      0,00%
# 2428 2014-03-05      5000       4955       5075      4945   23,96M      1,11%
# 2429 2014-03-04      4945       4910       4945      4910   12,32M      0,10%
# 2430 2014-03-03      4940       4900       4945      4885   11,51M      0,82%
#
# [2431 rows x 7 columns]

# %%
dataset = dataset.sort_values(by='Tanggal',
                              ascending = True,
                              ignore_index = True)
dataset
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah      Vol Perubahan%
# 0    2014-03-03      4940       4900       4945      4885   11,51M      0,82%
# 1    2014-03-04      4945       4910       4945      4910   12,32M      0,10%
# 2    2014-03-05      5000       4955       5075      4945   23,96M      1,11%
# 3    2014-03-06      5000       5050       5075      5000   12,10M      0,00%
# 4    2014-03-07      4960       5025       5050      4960    9,67M     -0,80%
# ...         ...       ...        ...        ...       ...      ...        ...
# 2426 2024-02-26      1135       1160       1160      1130   67,38M     -2,16%
# 2427 2024-02-27      1125       1140       1140      1120   71,32M     -0,88%
# 2428 2024-02-28      1115       1125       1125      1105   75,90M     -0,89%
# 2429 2024-02-29      1090       1115       1115      1090  132,02M     -2,24%
# 2430 2024-03-01      1105       1090       1110      1090   53,60M      1,38%
#
# [2431 rows x 7 columns]

# %%
dataset_B = dataset[dataset['Vol'].str.contains('B')]
print(dataset_B)
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah    Vol Perubahan%
# 1666 2021-01-14      1810       1620       1865      1590  1,07B     12,07%

# %%
dataset_M = dataset[dataset['Vol'].str.contains('M')]
print(dataset_M)
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah      Vol Perubahan%
# 0    2014-03-03      4940       4900       4945      4885   11,51M      0,82%
# 1    2014-03-04      4945       4910       4945      4910   12,32M      0,10%
# 2    2014-03-05      5000       4955       5075      4945   23,96M      1,11%
# 3    2014-03-06      5000       5050       5075      5000   12,10M      0,00%
# 4    2014-03-07      4960       5025       5050      4960    9,67M     -0,80%
# ...         ...       ...        ...        ...       ...      ...        ...
# 2426 2024-02-26      1135       1160       1160      1130   67,38M     -2,16%
# 2427 2024-02-27      1125       1140       1140      1120   71,32M     -0,88%
# 2428 2024-02-28      1115       1125       1125      1105   75,90M     -0,89%
# 2429 2024-02-29      1090       1115       1115      1090  132,02M     -2,24%
# 2430 2024-03-01      1105       1090       1110      1090   53,60M      1,38%
#
# [2430 rows x 7 columns]

# %%
dataset_K = dataset[dataset['Vol'].str.contains('K')]
print(dataset_K)
# Out:
# Empty DataFrame
# Columns: [Tanggal, Terakhir, Pembukaan, Tertinggi, Terendah, Vol, Perubahan%]
# Index: []

# %%
dataset = dataset.replace(to_replace = ',',
                          value = '.',
                          regex = True)
dataset
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah      Vol Perubahan%
# 0    2014-03-03      4940       4900       4945      4885   11.51M      0.82%
# 1    2014-03-04      4945       4910       4945      4910   12.32M      0.10%
# 2    2014-03-05      5000       4955       5075      4945   23.96M      1.11%
# 3    2014-03-06      5000       5050       5075      5000   12.10M      0.00%
# 4    2014-03-07      4960       5025       5050      4960    9.67M     -0.80%
# ...         ...       ...        ...        ...       ...      ...        ...
# 2426 2024-02-26      1135       1160       1160      1130   67.38M     -2.16%
# 2427 2024-02-27      1125       1140       1140      1120   71.32M     -0.88%
# 2428 2024-02-28      1115       1125       1125      1105   75.90M     -0.89%
# 2429 2024-02-29      1090       1115       1115      1090  132.02M     -2.24%
# 2430 2024-03-01      1105       1090       1110      1090   53.60M      1.38%
#
# [2431 rows x 7 columns]

# %%
def replace_value(value):
    if 'K' in value:
        return str(float(value.replace('K', '')) * 1000)
    elif 'M' in value:
        return str(float(value.replace('M', '')) * 1000000)
    elif 'B' in value:
        return str(float(value.replace('B', '')) * 1000000000)
    return value

dataset['Vol'] = dataset['Vol'].apply(replace_value)

dataset
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah                 Vol  \
# 0    2014-03-03      4940       4900       4945      4885          11510000.0
# 1    2014-03-04      4945       4910       4945      4910          12320000.0
# 2    2014-03-05      5000       4955       5075      4945          23960000.0
# 3    2014-03-06      5000       5050       5075      5000          12100000.0
# 4    2014-03-07      4960       5025       5050      4960           9670000.0
# ...         ...       ...        ...        ...       ...                 ...
# 2426 2024-02-26      1135       1160       1160      1130          67380000.0
# 2427 2024-02-27      1125       1140       1140      1120          71320000.0
# 2428 2024-02-28      1115       1125       1125      1105          75900000.0
# 2429 2024-02-29      1090       1115       1115      1090  132020000.00000001
# 2430 2024-03-01      1105       1090       1110      1090          53600000.0
#
#      Perubahan%
# 0         0.82%
# 1         0.10%
# 2         1.11%
# 3         0.00%
# 4        -0.80%
# ...         ...
# 2426     -2.16%
# 2427     -0.88%
# 2428     -0.89%
# 2429     -2.24%
# 2430      1.38%
#
# [2431 rows x 7 columns]

# %%
dataset.dtypes
# Out:
# Tanggal       datetime64[ns]
# Terakhir               int64
# Pembukaan              int64
# Tertinggi              int64
# Terendah               int64
# Vol                   object
# Perubahan%            object
# dtype: object

# %%
dataset = dataset.astype({'Terakhir': 'float32'})
dataset.dtypes
# Out:
# Tanggal       datetime64[ns]
# Terakhir             float32
# Pembukaan              int64
# Tertinggi              int64
# Terendah               int64
# Vol                   object
# Perubahan%            object
# dtype: object

# %%
dataset = dataset.astype({'Vol': 'float32'})
dataset.dtypes
# Out:
# Tanggal       datetime64[ns]
# Terakhir             float32
# Pembukaan              int64
# Tertinggi              int64
# Terendah               int64
# Vol                  float32
# Perubahan%            object
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2431 entries, 0 to 2430
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     2431 non-null   datetime64[ns]
#  1   Terakhir    2431 non-null   float32
#  2   Pembukaan   2431 non-null   int64
#  3   Tertinggi   2431 non-null   int64
#  4   Terendah    2431 non-null   int64
#  5   Vol         2431 non-null   float32
#  6   Perubahan%  2431 non-null   object
# dtypes: datetime64[ns](1), float32(2), int64(3), object(1)
# memory usage: 114.1+ KB

# %%
plt.figure(figsize=(60,10))

plt.subplot(1,2,1)
plt.plot(dataset['Tanggal'], dataset['Terakhir'])
plt.title('Harga Penutupan Saham PGAS/Hari', fontsize = 20)

plt.figure(figsize=(60,10))

plt.subplot(1,2,1)
plt.plot(dataset['Tanggal'], dataset['Vol'], 'g')
plt.title('Volume Transaksi Saham PGAS/Hari', fontsize = 20)

plt.show()

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu")
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
data_use = np.column_stack((dataset['Terakhir'], dataset['Vol']))
tanggal_data = pd.DataFrame({'Tanggal' : dataset['Tanggal']})

print(data_use)
print(tanggal_data)
# Out:
# [[4.9400e+03 1.1510e+07]
#  [4.9450e+03 1.2320e+07]
#  [5.0000e+03 2.3960e+07]
#  ...
#  [1.1150e+03 7.5900e+07]
#  [1.0900e+03 1.3202e+08]
#  [1.1050e+03 5.3600e+07]]
#         Tanggal
# 0    2014-03-03
# 1    2014-03-04
# 2    2014-03-05
# 3    2014-03-06
# 4    2014-03-07
# ...         ...
# 2426 2024-02-26
# 2427 2024-02-27
# 2428 2024-02-28
# 2429 2024-02-29
# 2430 2024-03-01
#
# [2431 rows x 1 columns]

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data_use)

# %%
seq_length = 1

x_train = []
y_train = []

seq_length = 10
for i in range (len(scaled_data) - seq_length):
    x_train.append(scaled_data[i:i + seq_length])
    y_train.append(scaled_data[i + seq_length, 0])
    
x_train = np.array(x_train)
y_train = np.array(y_train).reshape(-1, 1)

# %%
print(x_train)
print(y_train)
# Out:
# [[[0.77827644 0.00569255]
#   [0.7791741  0.00645343]
#   [0.78904843 0.01738763]
#   ...
#   [0.78635544 0.02848152]
#   [0.82046676 0.05098868]
#   [0.83842003 0.03957541]]
#
#  [[0.7791741  0.00645343]
#   [0.78904843 0.01738763]
#   [0.78904843 0.00624677]
#   ...
#   [0.82046676 0.05098868]
#   [0.83842003 0.03957541]
#   [0.8429084  0.02461134]]
#
#  [[0.78904843 0.01738763]
#   [0.78904843 0.00624677]
#   [0.7818671  0.00396412]
#   ...
#   [0.83842003 0.03957541]
#   [0.8429084  0.02461134]
#   [0.82046676 0.01948241]]
#
#  ...
#
#  [[0.0978456  0.01544314]
#   [0.10143626 0.04176413]
#   [0.10233393 0.02646189]
#   ...
#   [0.09964094 0.03245503]
#   [0.0951526  0.05817482]
#   [0.09335726 0.06187591]]
#
#  [[0.10143626 0.04176413]
#   [0.10233393 0.02646189]
#   [0.10323159 0.02457376]
#   ...
#   [0.0951526  0.05817482]
#   [0.09335726 0.06187591]
#   [0.09156194 0.0661782 ]]
#
#  [[0.10233393 0.02646189]
#   [0.10323159 0.02457376]
#   [0.1005386  0.02785214]
#   ...
#   [0.09335726 0.06187591]
#   [0.09156194 0.0661782 ]
#   [0.08707361 0.11889531]]]
# [[0.8429084 ]
#  [0.82046676]
#  [0.8025134 ]
#  ...
#  [0.09156194]
#  [0.08707361]
#  [0.08976661]]

# %%
train_size = int(len(x_train) * 0.9)
x_train, x_test = x_train[:train_size], x_train[train_size:]
y_train, y_test = y_train[:train_size], y_train[train_size:]
tanggal_train, tanggal_test = tanggal_data[seq_length:train_size+seq_length],tanggal_data[train_size+seq_length:]

print(x_train.shape)
print(y_train.shape)
print(tanggal_train.shape)
print(y_test.shape)
print(tanggal_test.shape)

print(tanggal_test)
# Out:
# (2178, 10, 2)
# (2178, 1)
# (2178, 1)
# (243, 1)
# (243, 1)
#         Tanggal
# 2188 2023-02-23
# 2189 2023-02-24
# 2190 2023-02-27
# 2191 2023-02-28
# 2192 2023-03-01
# ...         ...
# 2426 2024-02-26
# 2427 2024-02-27
# 2428 2024-02-28
# 2429 2024-02-29
# 2430 2024-03-01
#
# [243 rows x 1 columns]

# %%
x_train_tensor = torch.tensor(x_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
x_test_tensor = torch.tensor(x_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# %%
# Memastikan bentuk data benar
print(f"x_train_tensor shape: {x_train_tensor.shape}")  # (num_samples, seq_length, num_features)
print(f"y_train_tensor shape: {y_train_tensor.shape}")  # (num_samples, 1)
print(f"x_test_tensor shape: {x_test_tensor.shape}")    # (num_samples, seq_length, num_features)
print(f"y_test_tensor shape: {y_test_tensor.shape}")    # (num_samples, 1)

# Menampilkan contoh data dari x_train_tensor dan y_train_tensor
print("\nContoh data dari x_train_tensor:")
print(x_train_tensor[0])  # Menampilkan sampel pertama dari x_train_tensor

print("\nContoh data dari y_train_tensor:")
print(y_train_tensor[0])  # Menampilkan target pertama dari y_train_tensor
# Out:
# x_train_tensor shape: torch.Size([2178, 10, 2])
# y_train_tensor shape: torch.Size([2178, 1])
# x_test_tensor shape: torch.Size([243, 10, 2])
# y_test_tensor shape: torch.Size([243, 1])
#
# Contoh data dari x_train_tensor:
# tensor([[0.7783, 0.0057],
#         [0.7792, 0.0065],
#         [0.7890, 0.0174],
#         [0.7890, 0.0062],
#         [0.7819, 0.0040],
#         [0.7819, 0.0077],
#         [0.7738, 0.0151],
#         [0.7864, 0.0285],
#         [0.8205, 0.0510],
#         [0.8384, 0.0396]])
#
# Contoh data dari y_train_tensor:
# tensor([0.8429])

# %%
class StockPricePredictor(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(StockPricePredictor, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        
        self.lstm1 = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.gru1 = nn.GRU(hidden_size, hidden_size, num_layers, batch_first=True)
        self.lstm2 = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True)
        self.gru2 = nn.GRU(hidden_size, hidden_size, num_layers, batch_first=True)
        
        self.fc = nn.Linear(hidden_size, 1)
    
    def forward(self, x):
        h0_lstm1 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0_lstm1 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm1(x, (h0_lstm1, c0_lstm1))
        
        h0_gru1 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru1(out, h0_gru1)
        
        h0_lstm2 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0_lstm2 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm2(out, (h0_lstm2, c0_lstm2))
        
        h0_gru2 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru2(out, h0_gru2)
        
        out = self.fc(out[:, -1, :])
        return out

# %%
# Membuat TensorDataset dan DataLoader
train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
test_dataset = TensorDataset(x_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
print(f"x_train_tensor shape: {x_train_tensor.shape}")  # (num_samples, seq_length, num_features)
print(f"y_train_tensor shape: {y_train_tensor.shape}")  # (num_samples, 1)
print(f"x_test_tensor shape: {x_test_tensor.shape}")    # (num_samples, seq_length, num_features)
print(f"y_test_tensor shape: {y_test_tensor.shape}")    # (num_samples, 1)
# Out:
# x_train_tensor shape: torch.Size([2178, 10, 2])
# y_train_tensor shape: torch.Size([2178, 1])
# x_test_tensor shape: torch.Size([243, 10, 2])
# y_test_tensor shape: torch.Size([243, 1])

# %%
input_size = x_train_tensor.shape[2]  # number of features, in this case 2
hidden_size = 64
num_layers = 1
num_epochs = 50
learning_rate = 0.001

# Initialize model, loss function, optimizer
model = StockPricePredictor(input_size, hidden_size, num_layers)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

train_losses = []
val_losses = []

for epoch in range(num_epochs):
    model.train()
    epoch_train_loss = 0.0
    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        epoch_train_loss += loss.item()
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
    
    # Average training loss for this epoch
    train_losses.append(epoch_train_loss / len(train_loader))
    
    # Validation loss
    model.eval()
    epoch_val_loss = 0.0
    with torch.no_grad():
        for val_inputs, val_targets in test_loader:
            val_outputs = model(val_inputs)
            val_loss = criterion(val_outputs, val_targets)
            epoch_val_loss += val_loss.item()
    
    # Average validation loss for this epoch
    val_losses.append(epoch_val_loss / len(test_loader))
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {train_losses[-1]:.4f}, Validation Loss: {val_losses[-1]:.4f}')
# Out:
# Epoch [1/50], Loss: 0.0019
# Epoch [1/50], Training Loss: 0.0394, Validation Loss: 0.0019
# Epoch [2/50], Loss: 0.0000
# Epoch [2/50], Training Loss: 0.0013, Validation Loss: 0.0003
# Epoch [3/50], Loss: 0.0002
# Epoch [3/50], Training Loss: 0.0010, Validation Loss: 0.0003
# Epoch [4/50], Loss: 0.0001
# Epoch [4/50], Training Loss: 0.0009, Validation Loss: 0.0002
# Epoch [5/50], Loss: 0.0011
# Epoch [5/50], Training Loss: 0.0008, Validation Loss: 0.0002
# Epoch [6/50], Loss: 0.0001
# Epoch [6/50], Training Loss: 0.0008, Validation Loss: 0.0004
# Epoch [7/50], Loss: 0.0002
# Epoch [7/50], Training Loss: 0.0007, Validation Loss: 0.0002
# Epoch [8/50], Loss: 0.0010
# Epoch [8/50], Training Loss: 0.0007, Validation Loss: 0.0001
# Epoch [9/50], Loss: 0.0001
# Epoch [9/50], Training Loss: 0.0007, Validation Loss: 0.0001
# Epoch [10/50], Loss: 0.0014
# Epoch [10/50], Training Loss: 0.0007, Validation Loss: 0.0001
# Epoch [11/50], Loss: 0.0022
# Epoch [11/50], Training Loss: 0.0006, Validation Loss: 0.0004
# Epoch [12/50], Loss: 0.0004
# Epoch [12/50], Training Loss: 0.0007, Validation Loss: 0.0002
# Epoch [13/50], Loss: 0.0000
# Epoch [13/50], Training Loss: 0.0006, Validation Loss: 0.0002
# Epoch [14/50], Loss: 0.0000
# Epoch [14/50], Training Loss: 0.0005, Validation Loss: 0.0001
# Epoch [15/50], Loss: 0.0000
# Epoch [15/50], Training Loss: 0.0005, Validation Loss: 0.0001
# Epoch [16/50], Loss: 0.0003
# Epoch [16/50], Training Loss: 0.0005, Validation Loss: 0.0001
# Epoch [17/50], Loss: 0.0003
# Epoch [17/50], Training Loss: 0.0006, Validation Loss: 0.0002
# Epoch [18/50], Loss: 0.0011
# Epoch [18/50], Training Loss: 0.0005, Validation Loss: 0.0002
# Epoch [19/50], Loss: 0.0004
# Epoch [19/50], Training Loss: 0.0007, Validation Loss: 0.0001
# Epoch [20/50], Loss: 0.0000
# Epoch [20/50], Training Loss: 0.0005, Validation Loss: 0.0003
# Epoch [21/50], Loss: 0.0001
# Epoch [21/50], Training Loss: 0.0004, Validation Loss: 0.0001
# Epoch [22/50], Loss: 0.0003
# Epoch [22/50], Training Loss: 0.0004, Validation Loss: 0.0001
# Epoch [23/50], Loss: 0.0003
# Epoch [23/50], Training Loss: 0.0004, Validation Loss: 0.0000
# Epoch [24/50], Loss: 0.0010
# Epoch [24/50], Training Loss: 0.0004, Validation Loss: 0.0001
# Epoch [25/50], Loss: 0.0006
# Epoch [25/50], Training Loss: 0.0003, Validation Loss: 0.0000
# Epoch [26/50], Loss: 0.0001
# Epoch [26/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [27/50], Loss: 0.0001
# Epoch [27/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [28/50], Loss: 0.0007
# Epoch [28/50], Training Loss: 0.0003, Validation Loss: 0.0000
# Epoch [29/50], Loss: 0.0000
# Epoch [29/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [30/50], Loss: 0.0006
# Epoch [30/50], Training Loss: 0.0003, Validation Loss: 0.0005
# Epoch [31/50], Loss: 0.0001
# Epoch [31/50], Training Loss: 0.0004, Validation Loss: 0.0000
# Epoch [32/50], Loss: 0.0000
# Epoch [32/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [33/50], Loss: 0.0004
# Epoch [33/50], Training Loss: 0.0003, Validation Loss: 0.0000
# Epoch [34/50], Loss: 0.0000
# Epoch [34/50], Training Loss: 0.0002, Validation Loss: 0.0002
# Epoch [35/50], Loss: 0.0002
# Epoch [35/50], Training Loss: 0.0002, Validation Loss: 0.0000
# Epoch [36/50], Loss: 0.0000
# Epoch [36/50], Training Loss: 0.0002, Validation Loss: 0.0002
# Epoch [37/50], Loss: 0.0000
# Epoch [37/50], Training Loss: 0.0002, Validation Loss: 0.0000
# Epoch [38/50], Loss: 0.0003
# Epoch [38/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [39/50], Loss: 0.0006
# Epoch [39/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [40/50], Loss: 0.0003
# Epoch [40/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [41/50], Loss: 0.0000
# Epoch [41/50], Training Loss: 0.0002, Validation Loss: 0.0000
# Epoch [42/50], Loss: 0.0001
# Epoch [42/50], Training Loss: 0.0002, Validation Loss: 0.0000
# Epoch [43/50], Loss: 0.0001
# Epoch [43/50], Training Loss: 0.0002, Validation Loss: 0.0000
# Epoch [44/50], Loss: 0.0000
# Epoch [44/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [45/50], Loss: 0.0002
# Epoch [45/50], Training Loss: 0.0002, Validation Loss: 0.0000
# Epoch [46/50], Loss: 0.0007
# Epoch [46/50], Training Loss: 0.0002, Validation Loss: 0.0000
# Epoch [47/50], Loss: 0.0001
# Epoch [47/50], Training Loss: 0.0002, Validation Loss: 0.0000
# Epoch [48/50], Loss: 0.0001
# Epoch [48/50], Training Loss: 0.0002, Validation Loss: 0.0000
# Epoch [49/50], Loss: 0.0002
# Epoch [49/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [50/50], Loss: 0.0001
# Epoch [50/50], Training Loss: 0.0002, Validation Loss: 0.0001

# %%
# Visualize the training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Evaluation
model.eval()
with torch.no_grad():
    test_loss = 0
    predictions = []
    actuals = []
    for inputs, targets in test_loader:
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        test_loss += loss.item()
        predictions.extend(outputs.cpu().numpy())
        actuals.extend(targets.cpu().numpy())

test_loss /= len(test_loader)
print(f'Test Loss: {test_loss:.4f}')
# Out:
# Test Loss: 0.0001

# %%
# Convert predictions and actuals to numpy arrays
predictions = np.array(predictions)
actuals = np.array(actuals)

# %%
# Predictions
model.eval()
with torch.no_grad():
    predictions = []
    for inputs, _ in test_loader:
        outputs = model(inputs)
        predictions.extend(outputs.cpu().numpy())

predictions = np.array(predictions)
print(predictions[:10])  # Menampilkan 10 prediksi pertama
# Out:
# [[0.17785493]
#  [0.17589638]
#  [0.17430283]
#  [0.1753377 ]
#  [0.1798592 ]
#  [0.17911279]
#  [0.1854043 ]
#  [0.18461046]
#  [0.18678045]
#  [0.18112719]]

# %%
# Membuat DataFrame untuk perbandingan hasil prediksi dan nilai aktual
comparison_df = pd.DataFrame({
    'Predicted': predictions.flatten(),
    'Actual': actuals.flatten()
})

# Menampilkan DataFrame
print(comparison_df)
# Out:
#      Predicted    Actual
# 0     0.177855  0.166966
# 1     0.175896  0.165171
# 2     0.174303  0.166966
# 3     0.175338  0.172352
# 4     0.179859  0.169659
# ..         ...       ...
# 238   0.108359  0.095153
# 239   0.104396  0.093357
# 240   0.101723  0.091562
# 241   0.099886  0.087074
# 242   0.096487  0.089767
#
# [243 rows x 2 columns]

# %%
# Menghitung metrik
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(actuals, predictions)

# Menampilkan hasil
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAPE: {mape:.4%}")
# Out:
# MSE: 0.0001
# RMSE: 0.0096
# MAPE: 7.1696%

# %%
# Membuat Data Frame
train_df = pd.DataFrame({
    'Tanggal': tanggal_train['Tanggal'],
    'Value': y_train.flatten(),
    'Type': 'Train'
})

test_df = pd.DataFrame({
    'Tanggal': tanggal_test['Tanggal'],
    'Value': y_test.flatten(),
    'Type': 'Test'
})

predicted_df = pd.DataFrame({
    'Tanggal': tanggal_test['Tanggal'],
    'Value': predictions.flatten(),
    'Type': 'Predicted'
})

# %%
compact_df = pd.concat([test_df, predicted_df])

# %%
# Menggabungkan DataFrame
combined_df = pd.concat([train_df, test_df, predicted_df])

# Menampilkan DataFrame
print(combined_df)
# Out:
#         Tanggal     Value       Type
# 10   2014-03-17  0.842908      Train
# 11   2014-03-18  0.820467      Train
# 12   2014-03-19  0.802513      Train
# 13   2014-03-20  0.767504      Train
# 14   2014-03-21  0.820467      Train
# ...         ...       ...        ...
# 2426 2024-02-26  0.108359  Predicted
# 2427 2024-02-27  0.104396  Predicted
# 2428 2024-02-28  0.101723  Predicted
# 2429 2024-02-29  0.099886  Predicted
# 2430 2024-03-01  0.096487  Predicted
#
# [2664 rows x 3 columns]

# %%
# Plotting hasil prediksi dan nilai aktual
plt.figure(figsize=(10, 6))
for label, df in compact_df.groupby('Type'):
    plt.plot(df['Tanggal'], df['Value'], label=label)
plt.title('Prediksi Harga Saham PGAS \n 'f"Epoch = {num_epochs}"', Komposisi = 90:10 \n' f"MSE: {mse:.4f}" ', ' f"RMSE: {rmse:.4f}" ', ' f"MAPE: {mape:.4%}")
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.show()

# %%
# Plotting hasil prediksi dan nilai aktual
plt.figure(figsize=(10, 6))
for label, df in combined_df.groupby('Type'):
    plt.plot(df['Tanggal'], df['Value'], label=label)
plt.title('Prediksi Harga Saham PGAS \n 'f"Epoch = {num_epochs}"', Komposisi = 90:10 \n' f"MSE: {mse:.4f}" ', ' f"RMSE: {rmse:.4f}" ', ' f"MAPE: {mape:.4%}")
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.show()
