# %% [markdown]
# # Preprocessing

# %%
#Import Library yang diperlukan

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import sys
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, TensorDataset

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %%
#Import dataset

datapath = '../../../1. Data/Raw/Data Historis PTBA.csv'
dataset = pd.read_csv(datapath)
dataset
# Out:
#          Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah     Vol Perubahan%
# 0     01/03/2024      2580       2590       2610      2570   8,63M      0,78%
# 1     29/02/2024      2560       2620       2630      2560  16,56M     -2,29%
# 2     28/02/2024      2620       2600       2630      2600   5,27M      1,16%
# 3     27/02/2024      2590       2600       2610      2590   5,65M      0,39%
# 4     26/02/2024      2580       2640       2640      2580  11,68M     -1,90%
# ...          ...       ...        ...        ...       ...     ...        ...
# 2426  07/03/2014      9425       9600       9600      9400   2,41M     -1,05%
# 2427  06/03/2014      9525       9550       9575      9500   2,60M      0,00%
# 2428  05/03/2014      9525       9625       9650      9500   3,45M      0,00%
# 2429  04/03/2014      9525       9425       9600      9375   5,91M      1,87%
# 2430  03/03/2014      9350       9475       9500      9325   3,04M     -2,35%
#
# [2431 rows x 7 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2431 entries, 0 to 2430
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     2431 non-null   object
#  1   Terakhir    2431 non-null   int64
#  2   Pembukaan   2431 non-null   int64
#  3   Tertinggi   2431 non-null   int64
#  4   Terendah    2431 non-null   int64
#  5   Vol         2431 non-null   object
#  6   Perubahan%  2431 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 133.1+ KB

# %%
dataset.describe()
# Out:
#            Terakhir     Pembukaan     Tertinggi      Terendah
# count   2431.000000   2431.000000   2431.000000   2431.000000
# mean    4044.846977   4051.382559   4113.240642   3988.388318
# std     3046.771520   3047.802553   3093.134209   3005.955155
# min      833.000000    846.000000    859.000000    830.000000
# 25%     2292.500000   2300.000000   2340.000000   2260.000000
# 50%     2790.000000   2795.000000   2830.000000   2760.000000
# 75%     4130.000000   4140.000000   4180.000000   4080.000000
# max    13975.000000  14100.000000  14150.000000  13900.000000

# %%
dataset.isna().sum().to_frame(name='num_of_NaN')
# Out:
#             num_of_NaN
# Tanggal              0
# Terakhir             0
# Pembukaan            0
# Tertinggi            0
# Terendah             0
# Vol                  0
# Perubahan%           0

# %%
from datetime import datetime
dataset['Tanggal'] = pd.to_datetime(dataset['Tanggal'],
                                   format = '%d/%m/%Y')
dataset
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah     Vol Perubahan%
# 0    2024-03-01      2580       2590       2610      2570   8,63M      0,78%
# 1    2024-02-29      2560       2620       2630      2560  16,56M     -2,29%
# 2    2024-02-28      2620       2600       2630      2600   5,27M      1,16%
# 3    2024-02-27      2590       2600       2610      2590   5,65M      0,39%
# 4    2024-02-26      2580       2640       2640      2580  11,68M     -1,90%
# ...         ...       ...        ...        ...       ...     ...        ...
# 2426 2014-03-07      9425       9600       9600      9400   2,41M     -1,05%
# 2427 2014-03-06      9525       9550       9575      9500   2,60M      0,00%
# 2428 2014-03-05      9525       9625       9650      9500   3,45M      0,00%
# 2429 2014-03-04      9525       9425       9600      9375   5,91M      1,87%
# 2430 2014-03-03      9350       9475       9500      9325   3,04M     -2,35%
#
# [2431 rows x 7 columns]

# %%
dataset = dataset.sort_values(by='Tanggal',
                              ascending = True,
                              ignore_index = True)
dataset
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah     Vol Perubahan%
# 0    2014-03-03      9350       9475       9500      9325   3,04M     -2,35%
# 1    2014-03-04      9525       9425       9600      9375   5,91M      1,87%
# 2    2014-03-05      9525       9625       9650      9500   3,45M      0,00%
# 3    2014-03-06      9525       9550       9575      9500   2,60M      0,00%
# 4    2014-03-07      9425       9600       9600      9400   2,41M     -1,05%
# ...         ...       ...        ...        ...       ...     ...        ...
# 2426 2024-02-26      2580       2640       2640      2580  11,68M     -1,90%
# 2427 2024-02-27      2590       2600       2610      2590   5,65M      0,39%
# 2428 2024-02-28      2620       2600       2630      2600   5,27M      1,16%
# 2429 2024-02-29      2560       2620       2630      2560  16,56M     -2,29%
# 2430 2024-03-01      2580       2590       2610      2570   8,63M      0,78%
#
# [2431 rows x 7 columns]

# %%
dataset_B = dataset[dataset['Vol'].str.contains('B')]
print(dataset_B)
# Out:
# Empty DataFrame
# Columns: [Tanggal, Terakhir, Pembukaan, Tertinggi, Terendah, Vol, Perubahan%]
# Index: []

# %%
dataset_M = dataset[dataset['Vol'].str.contains('M')]
print(dataset_M)
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah     Vol Perubahan%
# 0    2014-03-03      9350       9475       9500      9325   3,04M     -2,35%
# 1    2014-03-04      9525       9425       9600      9375   5,91M      1,87%
# 2    2014-03-05      9525       9625       9650      9500   3,45M      0,00%
# 3    2014-03-06      9525       9550       9575      9500   2,60M      0,00%
# 4    2014-03-07      9425       9600       9600      9400   2,41M     -1,05%
# ...         ...       ...        ...        ...       ...     ...        ...
# 2426 2024-02-26      2580       2640       2640      2580  11,68M     -1,90%
# 2427 2024-02-27      2590       2600       2610      2590   5,65M      0,39%
# 2428 2024-02-28      2620       2600       2630      2600   5,27M      1,16%
# 2429 2024-02-29      2560       2620       2630      2560  16,56M     -2,29%
# 2430 2024-03-01      2580       2590       2610      2570   8,63M      0,78%
#
# [2398 rows x 7 columns]

# %%
dataset_K = dataset[dataset['Vol'].str.contains('K')]
print(dataset_K)
# Out:
#        Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah      Vol Perubahan%
# 22  2014-04-03      9425       9400       9450      9400  840,00K     -0,26%
# 107 2014-08-15     12775      12900      12975     12750  917,60K     -0,97%
# 128 2014-09-15     13125      13000      13250     13000  932,20K     -1,13%
# 143 2014-10-06     12800      12975      12975     12700  551,20K     -0,58%
# 157 2014-10-24     12275      12500      12575     12275  529,40K     -1,41%
# 163 2014-11-03     12800      13200      13200     12650  861,60K     -1,16%
# 166 2014-11-06     12575      12675      12750     12575  720,00K     -0,79%
# 167 2014-11-07     12550      12600      12725     12450  445,00K     -0,20%
# 168 2014-11-10     12650      12600      12750     12600  445,30K      0,80%
# 169 2014-11-11     12875      12600      12925     12600  734,20K      1,78%
# 170 2014-11-12     12600      13000      13000     12525  909,60K     -2,14%
# 171 2014-11-13     12350      12750      12750     12325  984,40K     -1,98%
# 200 2014-12-24     12625      12550      12700     12550  930,20K      0,80%
# 201 2014-12-29     12525      12675      12750     12500  921,00K     -0,79%
# 204 2015-01-05     12350      12325      12375     12200  982,90K     -0,20%
# 229 2015-02-09     11400      11600      11625     11350  849,80K     -1,72%
# 271 2015-04-10     10700      10800      10800     10625  441,00K     -0,47%
# 273 2015-04-14     10400      10400      10500     10325  834,40K     -0,48%
# 276 2015-04-17     10750      10750      10775     10675  949,60K      0,00%
# 277 2015-04-20     10600      10750      10750     10575  681,60K     -1,40%
# 281 2015-04-24     10525      10500      10625     10500  493,80K      1,20%
# 289 2015-05-07      9200       9350       9350      9200  902,30K     -1,60%
# 296 2015-05-19     10425      10500      10525     10350  747,40K     -0,24%
# 300 2015-05-25     10375      10550      10600     10300  796,40K     -1,66%
# 314 2015-06-15      9075       9250       9250      9050  636,40K     -0,82%
# 319 2015-06-22      9000       9075       9075      8950  865,40K     -0,28%
# 320 2015-06-23      8950       9075       9075      8925  961,50K     -0,56%
# 324 2015-06-29      8375       8500       8500      8300  641,40K     -1,47%
# 328 2015-07-03      8275       8300       8300      8250  921,80K      0,30%
# 329 2015-07-06      8200       8300       8300      8175  852,60K     -0,91%
# 369 2015-09-07      5850       6000       6000      5825  718,00K     -2,50%
# 380 2015-09-22      5575       5725       5725      5575  793,70K     -0,89%
# 387 2015-10-02      5575       5625       5650      5575  719,30K     -0,89%

# %%
dataset = dataset.replace(to_replace = ',',
                          value = '.',
                          regex = True)
dataset
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah     Vol Perubahan%
# 0    2014-03-03      9350       9475       9500      9325   3.04M     -2.35%
# 1    2014-03-04      9525       9425       9600      9375   5.91M      1.87%
# 2    2014-03-05      9525       9625       9650      9500   3.45M      0.00%
# 3    2014-03-06      9525       9550       9575      9500   2.60M      0.00%
# 4    2014-03-07      9425       9600       9600      9400   2.41M     -1.05%
# ...         ...       ...        ...        ...       ...     ...        ...
# 2426 2024-02-26      2580       2640       2640      2580  11.68M     -1.90%
# 2427 2024-02-27      2590       2600       2610      2590   5.65M      0.39%
# 2428 2024-02-28      2620       2600       2630      2600   5.27M      1.16%
# 2429 2024-02-29      2560       2620       2630      2560  16.56M     -2.29%
# 2430 2024-03-01      2580       2590       2610      2570   8.63M      0.78%
#
# [2431 rows x 7 columns]

# %%
def replace_value(value):
    if 'K' in value:
        return str(float(value.replace('K', '')) * 1000)
    elif 'M' in value:
        return str(float(value.replace('M', '')) * 1000000)
    elif 'B' in value:
        return str(float(value.replace('B', '')) * 1000000000)
    return value

dataset['Vol'] = dataset['Vol'].apply(replace_value)

dataset
# Out:
#         Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah                 Vol  \
# 0    2014-03-03      9350       9475       9500      9325           3040000.0
# 1    2014-03-04      9525       9425       9600      9375           5910000.0
# 2    2014-03-05      9525       9625       9650      9500           3450000.0
# 3    2014-03-06      9525       9550       9575      9500           2600000.0
# 4    2014-03-07      9425       9600       9600      9400           2410000.0
# ...         ...       ...        ...        ...       ...                 ...
# 2426 2024-02-26      2580       2640       2640      2580          11680000.0
# 2427 2024-02-27      2590       2600       2610      2590           5650000.0
# 2428 2024-02-28      2620       2600       2630      2600           5270000.0
# 2429 2024-02-29      2560       2620       2630      2560  16559999.999999998
# 2430 2024-03-01      2580       2590       2610      2570           8630000.0
#
#      Perubahan%
# 0        -2.35%
# 1         1.87%
# 2         0.00%
# 3         0.00%
# 4        -1.05%
# ...         ...
# 2426     -1.90%
# 2427      0.39%
# 2428      1.16%
# 2429     -2.29%
# 2430      0.78%
#
# [2431 rows x 7 columns]

# %%
dataset.dtypes
# Out:
# Tanggal       datetime64[ns]
# Terakhir               int64
# Pembukaan              int64
# Tertinggi              int64
# Terendah               int64
# Vol                   object
# Perubahan%            object
# dtype: object

# %%
dataset = dataset.astype({'Terakhir': 'float32'})
dataset.dtypes
# Out:
# Tanggal       datetime64[ns]
# Terakhir             float32
# Pembukaan              int64
# Tertinggi              int64
# Terendah               int64
# Vol                   object
# Perubahan%            object
# dtype: object

# %%
dataset = dataset.astype({'Vol': 'float32'})
dataset.dtypes
# Out:
# Tanggal       datetime64[ns]
# Terakhir             float32
# Pembukaan              int64
# Tertinggi              int64
# Terendah               int64
# Vol                  float32
# Perubahan%            object
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2431 entries, 0 to 2430
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     2431 non-null   datetime64[ns]
#  1   Terakhir    2431 non-null   float32
#  2   Pembukaan   2431 non-null   int64
#  3   Tertinggi   2431 non-null   int64
#  4   Terendah    2431 non-null   int64
#  5   Vol         2431 non-null   float32
#  6   Perubahan%  2431 non-null   object
# dtypes: datetime64[ns](1), float32(2), int64(3), object(1)
# memory usage: 114.1+ KB

# %%
plt.figure(figsize=(60,10))

plt.subplot(1,2,1)
plt.plot(dataset['Tanggal'], dataset['Terakhir'])
plt.title('Harga Penutupan Saham PTBA/Hari', fontsize = 20)

plt.figure(figsize=(60,10))

plt.subplot(1,2,1)
plt.plot(dataset['Tanggal'], dataset['Vol'], 'g')
plt.title('Volume Transaksi Saham PTBA/Hari', fontsize = 20)

plt.show()

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu")
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
data_use = np.column_stack((dataset['Terakhir'], dataset['Vol']))
tanggal_data = pd.DataFrame({'Tanggal' : dataset['Tanggal']})

print(data_use)
print(tanggal_data)
# Out:
# [[9.350e+03 3.040e+06]
#  [9.525e+03 5.910e+06]
#  [9.525e+03 3.450e+06]
#  ...
#  [2.620e+03 5.270e+06]
#  [2.560e+03 1.656e+07]
#  [2.580e+03 8.630e+06]]
#         Tanggal
# 0    2014-03-03
# 1    2014-03-04
# 2    2014-03-05
# 3    2014-03-06
# 4    2014-03-07
# ...         ...
# 2426 2024-02-26
# 2427 2024-02-27
# 2428 2024-02-28
# 2429 2024-02-29
# 2430 2024-03-01
#
# [2431 rows x 1 columns]

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data_use)

# %%
seq_length = 1

x_train = []
y_train = []

seq_length = 10
for i in range (len(scaled_data) - seq_length):
    x_train.append(scaled_data[i:i + seq_length])
    y_train.append(scaled_data[i + seq_length, 0])
    
x_train = np.array(x_train)
y_train = np.array(y_train).reshape(-1, 1)

# %%
print(x_train)
print(y_train)
# Out:
# [[[0.64807487 0.00713934]
#   [0.66139096 0.01502312]
#   [0.66139096 0.0082656 ]
#   ...
#   [0.64236796 0.00774368]
#   [0.64997715 0.00334854]
#   [0.6404657  0.00947426]]
#
#  [[0.66139096 0.01502312]
#   [0.66139096 0.0082656 ]
#   [0.66139096 0.00593068]
#   ...
#   [0.64997715 0.00334854]
#   [0.6404657  0.00947426]
#   [0.64236796 0.00969402]]
#
#  [[0.66139096 0.0082656 ]
#   [0.66139096 0.00593068]
#   [0.6537818  0.00540876]
#   ...
#   [0.6404657  0.00947426]
#   [0.64236796 0.00969402]
#   [0.64236796 0.00744151]]
#
#  ...
#
#  [[0.13749811 0.0142265 ]
#   [0.13901994 0.02809864]
#   [0.14054179 0.03474628]
#   ...
#   [0.13673717 0.00958414]
#   [0.13293257 0.03087307]
#   [0.13369352 0.01430891]]
#
#  [[0.13901994 0.02809864]
#   [0.14054179 0.03474628]
#   [0.1413027  0.02636805]
#   ...
#   [0.13293257 0.03087307]
#   [0.13369352 0.01430891]
#   [0.13597625 0.01326506]]
#
#  [[0.14054179 0.03474628]
#   [0.1413027  0.02636805]
#   [0.13749811 0.0243353 ]
#   ...
#   [0.13369352 0.01430891]
#   [0.13597625 0.01326506]
#   [0.13141075 0.04427822]]]
# [[0.64236796]
#  [0.64236796]
#  [0.64997715]
#  ...
#  [0.13597625]
#  [0.13141075]
#  [0.13293257]]

# %%
train_size = int(len(x_train) * 0.8)
x_train, x_test = x_train[:train_size], x_train[train_size:]
y_train, y_test = y_train[:train_size], y_train[train_size:]
tanggal_train, tanggal_test = tanggal_data[seq_length:train_size+seq_length], tanggal_data[train_size+seq_length:]

print(x_train.shape)
print(y_train.shape)
print(tanggal_train.shape)
print(y_test.shape)
print(tanggal_test.shape)

print(tanggal_test)
# Out:
# (1936, 10, 2)
# (1936, 1)
# (1936, 1)
# (485, 1)
# (485, 1)
#         Tanggal
# 1946 2022-03-04
# 1947 2022-03-07
# 1948 2022-03-08
# 1949 2022-03-09
# 1950 2022-03-10
# ...         ...
# 2426 2024-02-26
# 2427 2024-02-27
# 2428 2024-02-28
# 2429 2024-02-29
# 2430 2024-03-01
#
# [485 rows x 1 columns]

# %%
x_train_tensor = torch.tensor(x_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
x_test_tensor = torch.tensor(x_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# %%
# Memastikan bentuk data benar
print(f"x_train_tensor shape: {x_train_tensor.shape}")  # (num_samples, seq_length, num_features)
print(f"y_train_tensor shape: {y_train_tensor.shape}")  # (num_samples, 1)
print(f"x_test_tensor shape: {x_test_tensor.shape}")    # (num_samples, seq_length, num_features)
print(f"y_test_tensor shape: {y_test_tensor.shape}")    # (num_samples, 1)

# Menampilkan contoh data dari x_train_tensor dan y_train_tensor
print("\nContoh data dari x_train_tensor:")
print(x_train_tensor[0])  # Menampilkan sampel pertama dari x_train_tensor

print("\nContoh data dari y_train_tensor:")
print(y_train_tensor[0])  # Menampilkan target pertama dari y_train_tensor
# Out:
# x_train_tensor shape: torch.Size([1936, 10, 2])
# y_train_tensor shape: torch.Size([1936, 1])
# x_test_tensor shape: torch.Size([485, 10, 2])
# y_test_tensor shape: torch.Size([485, 1])
#
# Contoh data dari x_train_tensor:
# tensor([[0.6481, 0.0071],
#         [0.6614, 0.0150],
#         [0.6614, 0.0083],
#         [0.6614, 0.0059],
#         [0.6538, 0.0054],
#         [0.6614, 0.0055],
#         [0.6633, 0.0053],
#         [0.6424, 0.0077],
#         [0.6500, 0.0033],
#         [0.6405, 0.0095]])
#
# Contoh data dari y_train_tensor:
# tensor([0.6424])

# %%
class StockPricePredictor(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(StockPricePredictor, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        
        self.lstm1 = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.gru1 = nn.GRU(hidden_size, hidden_size, num_layers, batch_first=True)
        self.lstm2 = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True)
        self.gru2 = nn.GRU(hidden_size, hidden_size, num_layers, batch_first=True)
        
        self.fc = nn.Linear(hidden_size, 1)
    
    def forward(self, x):
        h0_lstm1 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0_lstm1 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm1(x, (h0_lstm1, c0_lstm1))
        
        h0_gru1 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru1(out, h0_gru1)
        
        h0_lstm2 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0_lstm2 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm2(out, (h0_lstm2, c0_lstm2))
        
        h0_gru2 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.gru2(out, h0_gru2)
        
        out = self.fc(out[:, -1, :])
        return out

# %%
# Membuat TensorDataset dan DataLoader
train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
test_dataset = TensorDataset(x_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
print(f"x_train_tensor shape: {x_train_tensor.shape}")  # (num_samples, seq_length, num_features)
print(f"y_train_tensor shape: {y_train_tensor.shape}")  # (num_samples, 1)
print(f"x_test_tensor shape: {x_test_tensor.shape}")    # (num_samples, seq_length, num_features)
print(f"y_test_tensor shape: {y_test_tensor.shape}")    # (num_samples, 1)
# Out:
# x_train_tensor shape: torch.Size([1936, 10, 2])
# y_train_tensor shape: torch.Size([1936, 1])
# x_test_tensor shape: torch.Size([485, 10, 2])
# y_test_tensor shape: torch.Size([485, 1])

# %%
input_size = x_train_tensor.shape[2]  # number of features, in this case 2
hidden_size = 64
num_layers = 2
num_epochs = 50
learning_rate = 0.001

# Initialize model, loss function, optimizer
model = StockPricePredictor(input_size, hidden_size, num_layers)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

train_losses = []
val_losses = []

for epoch in range(num_epochs):
    model.train()
    epoch_train_loss = 0.0
    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        epoch_train_loss += loss.item()
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
    
    # Average training loss for this epoch
    train_losses.append(epoch_train_loss / len(train_loader))
    
    # Validation loss
    model.eval()
    epoch_val_loss = 0.0
    with torch.no_grad():
        for val_inputs, val_targets in test_loader:
            val_outputs = model(val_inputs)
            val_loss = criterion(val_outputs, val_targets)
            epoch_val_loss += val_loss.item()
    
    # Average validation loss for this epoch
    val_losses.append(epoch_val_loss / len(test_loader))
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {train_losses[-1]:.4f}, Validation Loss: {val_losses[-1]:.4f}')
# Out:
# Epoch [1/50], Loss: 0.0080
# Epoch [1/50], Training Loss: 0.0492, Validation Loss: 0.0036
# Epoch [2/50], Loss: 0.0013
# Epoch [2/50], Training Loss: 0.0043, Validation Loss: 0.0006
# Epoch [3/50], Loss: 0.0024
# Epoch [3/50], Training Loss: 0.0021, Validation Loss: 0.0004
# Epoch [4/50], Loss: 0.0016
# Epoch [4/50], Training Loss: 0.0017, Validation Loss: 0.0004
# Epoch [5/50], Loss: 0.0021
# Epoch [5/50], Training Loss: 0.0016, Validation Loss: 0.0003
# Epoch [6/50], Loss: 0.0022
# Epoch [6/50], Training Loss: 0.0020, Validation Loss: 0.0004
# Epoch [7/50], Loss: 0.0011
# Epoch [7/50], Training Loss: 0.0019, Validation Loss: 0.0007
# Epoch [8/50], Loss: 0.0003
# Epoch [8/50], Training Loss: 0.0018, Validation Loss: 0.0016
# Epoch [9/50], Loss: 0.0017
# Epoch [9/50], Training Loss: 0.0015, Validation Loss: 0.0003
# Epoch [10/50], Loss: 0.0100
# Epoch [10/50], Training Loss: 0.0014, Validation Loss: 0.0016
# Epoch [11/50], Loss: 0.0021
# Epoch [11/50], Training Loss: 0.0016, Validation Loss: 0.0003
# Epoch [12/50], Loss: 0.0004
# Epoch [12/50], Training Loss: 0.0016, Validation Loss: 0.0003
# Epoch [13/50], Loss: 0.0003
# Epoch [13/50], Training Loss: 0.0016, Validation Loss: 0.0003
# Epoch [14/50], Loss: 0.0006
# Epoch [14/50], Training Loss: 0.0013, Validation Loss: 0.0003
# Epoch [15/50], Loss: 0.0014
# Epoch [15/50], Training Loss: 0.0015, Validation Loss: 0.0003
# Epoch [16/50], Loss: 0.0013
# Epoch [16/50], Training Loss: 0.0013, Validation Loss: 0.0003
# Epoch [17/50], Loss: 0.0003
# Epoch [17/50], Training Loss: 0.0012, Validation Loss: 0.0004
# Epoch [18/50], Loss: 0.0007
# Epoch [18/50], Training Loss: 0.0011, Validation Loss: 0.0007
# Epoch [19/50], Loss: 0.0003
# Epoch [19/50], Training Loss: 0.0014, Validation Loss: 0.0003
# Epoch [20/50], Loss: 0.0008
# Epoch [20/50], Training Loss: 0.0010, Validation Loss: 0.0003
# Epoch [21/50], Loss: 0.0006
# Epoch [21/50], Training Loss: 0.0010, Validation Loss: 0.0005
# Epoch [22/50], Loss: 0.0011
# Epoch [22/50], Training Loss: 0.0010, Validation Loss: 0.0003
# Epoch [23/50], Loss: 0.0014
# Epoch [23/50], Training Loss: 0.0011, Validation Loss: 0.0003
# Epoch [24/50], Loss: 0.0012
# Epoch [24/50], Training Loss: 0.0010, Validation Loss: 0.0002
# Epoch [25/50], Loss: 0.0007
# Epoch [25/50], Training Loss: 0.0009, Validation Loss: 0.0002
# Epoch [26/50], Loss: 0.0004
# Epoch [26/50], Training Loss: 0.0007, Validation Loss: 0.0002
# Epoch [27/50], Loss: 0.0005
# Epoch [27/50], Training Loss: 0.0006, Validation Loss: 0.0002
# Epoch [28/50], Loss: 0.0003
# Epoch [28/50], Training Loss: 0.0005, Validation Loss: 0.0002
# Epoch [29/50], Loss: 0.0005
# Epoch [29/50], Training Loss: 0.0005, Validation Loss: 0.0002
# Epoch [30/50], Loss: 0.0008
# Epoch [30/50], Training Loss: 0.0005, Validation Loss: 0.0001
# Epoch [31/50], Loss: 0.0079
# Epoch [31/50], Training Loss: 0.0006, Validation Loss: 0.0005
# Epoch [32/50], Loss: 0.0001
# Epoch [32/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [33/50], Loss: 0.0003
# Epoch [33/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [34/50], Loss: 0.0001
# Epoch [34/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [35/50], Loss: 0.0004
# Epoch [35/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [36/50], Loss: 0.0001
# Epoch [36/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [37/50], Loss: 0.0001
# Epoch [37/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [38/50], Loss: 0.0004
# Epoch [38/50], Training Loss: 0.0004, Validation Loss: 0.0001
# Epoch [39/50], Loss: 0.0001
# Epoch [39/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [40/50], Loss: 0.0001
# Epoch [40/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [41/50], Loss: 0.0001
# Epoch [41/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [42/50], Loss: 0.0005
# Epoch [42/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [43/50], Loss: 0.0004
# Epoch [43/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [44/50], Loss: 0.0001
# Epoch [44/50], Training Loss: 0.0002, Validation Loss: 0.0001
# Epoch [45/50], Loss: 0.0001
# Epoch [45/50], Training Loss: 0.0004, Validation Loss: 0.0001
# Epoch [46/50], Loss: 0.0003
# Epoch [46/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [47/50], Loss: 0.0002
# Epoch [47/50], Training Loss: 0.0002, Validation Loss: 0.0000
# Epoch [48/50], Loss: 0.0013
# Epoch [48/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [49/50], Loss: 0.0001
# Epoch [49/50], Training Loss: 0.0003, Validation Loss: 0.0001
# Epoch [50/50], Loss: 0.0002
# Epoch [50/50], Training Loss: 0.0003, Validation Loss: 0.0001

# %%
# Visualize the training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Evaluation
model.eval()
with torch.no_grad():
    test_loss = 0
    predictions = []
    actuals = []
    for inputs, targets in test_loader:
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        test_loss += loss.item()
        predictions.extend(outputs.cpu().numpy())
        actuals.extend(targets.cpu().numpy())

test_loss /= len(test_loader)
print(f'Test Loss: {test_loss:.4f}')
# Out:
# Test Loss: 0.0001

# %%
# Convert predictions and actuals to numpy arrays
predictions = np.array(predictions)
actuals = np.array(actuals)

# %%
# Predictions
model.eval()
with torch.no_grad():
    predictions = []
    for inputs, _ in test_loader:
        outputs = model(inputs)
        predictions.extend(outputs.cpu().numpy())

predictions = np.array(predictions)
print(predictions[:10])  # Menampilkan 10 prediksi pertama
# Out:
# [[0.17897326]
#  [0.19393682]
#  [0.20632781]
#  [0.20405246]
#  [0.20313098]
#  [0.1989986 ]
#  [0.1977139 ]
#  [0.18916468]
#  [0.18495516]
#  [0.1878281 ]]

# %%
# Membuat DataFrame untuk perbandingan hasil prediksi dan nilai aktual
comparison_df = pd.DataFrame({
    'Predicted': predictions.flatten(),
    'Actual': actuals.flatten()
})

# Menampilkan DataFrame
print(comparison_df)
# Out:
#      Predicted    Actual
# 0     0.178973  0.205981
# 1     0.193937  0.212068
# 2     0.206328  0.201415
# 3     0.204052  0.205981
# 4     0.203131  0.200654
# ..         ...       ...
# 480   0.132462  0.132933
# 481   0.130591  0.133694
# 482   0.129792  0.135976
# 483   0.130875  0.131411
# 484   0.129252  0.132933
#
# [485 rows x 2 columns]

# %%
# Menghitung metrik
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(actuals, predictions)

# Menampilkan hasil
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAPE: {mape:.4%}")
# Out:
# MSE: 0.0001
# RMSE: 0.0077
# MAPE: 2.9278%

# %%
# Membuat Data Frame
train_df = pd.DataFrame({
    'Tanggal': tanggal_train['Tanggal'],
    'Value': y_train.flatten(),
    'Type': 'Train'
})

test_df = pd.DataFrame({
    'Tanggal': tanggal_test['Tanggal'],
    'Value': y_test.flatten(),
    'Type': 'Test'
})

predicted_df = pd.DataFrame({
    'Tanggal': tanggal_test['Tanggal'],
    'Value': predictions.flatten(),
    'Type': 'Predicted'
})

# %%
compact_df = pd.concat([test_df, predicted_df])

# %%
# Menggabungkan DataFrame
combined_df = pd.concat([train_df, test_df, predicted_df])

# Menampilkan DataFrame
print(combined_df)
# Out:
#         Tanggal     Value       Type
# 10   2014-03-17  0.642368      Train
# 11   2014-03-18  0.642368      Train
# 12   2014-03-19  0.649977      Train
# 13   2014-03-20  0.632856      Train
# 14   2014-03-21  0.648075      Train
# ...         ...       ...        ...
# 2426 2024-02-26  0.132462  Predicted
# 2427 2024-02-27  0.130591  Predicted
# 2428 2024-02-28  0.129792  Predicted
# 2429 2024-02-29  0.130875  Predicted
# 2430 2024-03-01  0.129252  Predicted
#
# [2906 rows x 3 columns]

# %%
# Plotting hasil prediksi dan nilai aktual
plt.figure(figsize=(10, 6))
for label, df in compact_df.groupby('Type'):
    plt.plot(df['Tanggal'], df['Value'], label=label)
plt.title('Prediksi Harga Saham PTBA \n Epoch = 50, Komposisi = 80:20 \n' f"MSE: {mse:.4f}" ', ' f"RMSE: {rmse:.4f}" ', ' f"MAPE: {mape:.4%}")
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.show()

# %%
# Plotting hasil prediksi dan nilai aktual
plt.figure(figsize=(10, 6))
for label, df in combined_df.groupby('Type'):
    plt.plot(df['Tanggal'], df['Value'], label=label)
plt.title('Prediksi Harga Saham PTBA \n Epoch = 50, Komposisi = 80:20 \n' f"MSE: {mse:.4f}" ', ' f"RMSE: {rmse:.4f}" ', ' f"MAPE: {mape:.4%}")
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.show()

# %% [markdown]
# # Prediksi Harga 1 Bulan Kedepan 10 Juni - 8 July

# %%
#Import dataset

datapath_new = 'data/Data Historis PTBA 1 Bulan.csv'
dataset_new = pd.read_csv(datapath_new)
dataset_new
# Out:
#        Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah     Vol Perubahan%
# 0   07/06/2024      2530       2520       2550      2510   7,71M      0,80%
# 1   06/06/2024      2510       2530       2540      2500   4,89M     -0,79%
# 2   05/06/2024      2530       2570       2580      2500  10,33M     -1,56%
# 3   04/06/2024      2570       2590       2590      2560  11,33M     -0,39%
# 4   03/06/2024      2580       2500       2590      2500  16,72M      3,61%
# 5   31/05/2024      2490       2500       2520      2490  15,71M      0,00%
# 6   30/05/2024      2490       2470       2500      2420   9,64M      0,81%
# 7   29/05/2024      2470       2520       2530      2460  14,74M     -1,59%
# 8   28/05/2024      2510       2540       2560      2510  11,91M     -0,40%
# 9   27/05/2024      2520       2600       2600      2520  21,41M     -2,70%
# 10  22/05/2024      2590       2570       2600      2570  18,23M      0,78%
# 11  21/05/2024      2570       2550       2640      2530  63,14M    -12,29%
# 12  20/05/2024      2930       2930       2960      2910  72,08M      0,34%
# 13  17/05/2024      2920       2930       2950      2910  30,77M     -0,34%
# 14  16/05/2024      2930       2920       2930      2900  21,54M      0,69%
# 15  15/05/2024      2910       2940       2950      2900  16,34M     -0,34%
# 16  14/05/2024      2920       2940       2960      2920  22,33M     -0,34%
# 17  13/05/2024      2930       2950       2970      2910  20,60M      0,00%
# 18  08/05/2024      2930       2900       3020      2790  89,51M      1,74%
# 19  07/05/2024      2880       2940       2950      2870  19,84M     -1,71%
# 20  06/05/2024      2930       2940       2950      2910  14,82M      0,00%
# 21  03/05/2024      2930       2910       2950      2890  15,12M      1,38%
# 22  02/05/2024      2890       2760       2920      2750  45,40M     -4,62%
# 23  30/04/2024      3030       3000       3030      2980  14,32M      1,00%
# 24  29/04/2024      3000       2900       3000      2860  11,27M      4,17%
# 25  26/04/2024      2880       2900       2940      2880  11,56M     -0,35%
# 26  25/04/2024      2890       2960       2960      2870  23,58M     -2,36%
# 27  24/04/2024      2960       3080       3100      2870  31,02M     -3,27%
# 28  23/04/2024      3060       3080       3090      3050   8,42M     -0,65%
# 29  22/04/2024      3080       3140       3150      3060  19,62M     -1,91%
# 30  19/04/2024      3140       3130       3150      3090  22,92M      0,32%
# 31  18/04/2024      3130       3100       3130      3030  26,81M      1,29%
# 32  17/04/2024      3090       3120       3160      3060  36,78M     -0,32%
# 33  16/04/2024      3100       2940       3130      2930  58,08M      5,80%

# %%
dataset_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     34 non-null     object
#  1   Terakhir    34 non-null     int64
#  2   Pembukaan   34 non-null     int64
#  3   Tertinggi   34 non-null     int64
#  4   Terendah    34 non-null     int64
#  5   Vol         34 non-null     object
#  6   Perubahan%  34 non-null     object
# dtypes: int64(4), object(3)
# memory usage: 2.0+ KB

# %%
dataset_new.describe()
# Out:
#           Terakhir    Pembukaan    Tertinggi     Terendah
# count    34.000000    34.000000    34.000000    34.000000
# mean   2818.235294  2819.705882  2857.352941  2776.764706
# std     227.961594   225.435408   229.377403   216.020770
# min    2470.000000  2470.000000  2500.000000  2420.000000
# 25%    2570.000000  2570.000000  2592.500000  2522.500000
# 50%    2915.000000  2915.000000  2950.000000  2870.000000
# 75%    2952.500000  2947.500000  3015.000000  2910.000000
# max    3140.000000  3140.000000  3160.000000  3090.000000

# %%
dataset_new.isna().sum().to_frame(name='num_of_NaN')
# Out:
#             num_of_NaN
# Tanggal              0
# Terakhir             0
# Pembukaan            0
# Tertinggi            0
# Terendah             0
# Vol                  0
# Perubahan%           0

# %%
dataset_new['Tanggal'] = pd.to_datetime(dataset_new['Tanggal'],
                                   format = '%d/%m/%Y')
dataset_new
# Out:
#       Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah     Vol Perubahan%
# 0  2024-06-07      2530       2520       2550      2510   7,71M      0,80%
# 1  2024-06-06      2510       2530       2540      2500   4,89M     -0,79%
# 2  2024-06-05      2530       2570       2580      2500  10,33M     -1,56%
# 3  2024-06-04      2570       2590       2590      2560  11,33M     -0,39%
# 4  2024-06-03      2580       2500       2590      2500  16,72M      3,61%
# 5  2024-05-31      2490       2500       2520      2490  15,71M      0,00%
# 6  2024-05-30      2490       2470       2500      2420   9,64M      0,81%
# 7  2024-05-29      2470       2520       2530      2460  14,74M     -1,59%
# 8  2024-05-28      2510       2540       2560      2510  11,91M     -0,40%
# 9  2024-05-27      2520       2600       2600      2520  21,41M     -2,70%
# 10 2024-05-22      2590       2570       2600      2570  18,23M      0,78%
# 11 2024-05-21      2570       2550       2640      2530  63,14M    -12,29%
# 12 2024-05-20      2930       2930       2960      2910  72,08M      0,34%
# 13 2024-05-17      2920       2930       2950      2910  30,77M     -0,34%
# 14 2024-05-16      2930       2920       2930      2900  21,54M      0,69%
# 15 2024-05-15      2910       2940       2950      2900  16,34M     -0,34%
# 16 2024-05-14      2920       2940       2960      2920  22,33M     -0,34%
# 17 2024-05-13      2930       2950       2970      2910  20,60M      0,00%
# 18 2024-05-08      2930       2900       3020      2790  89,51M      1,74%
# 19 2024-05-07      2880       2940       2950      2870  19,84M     -1,71%
# 20 2024-05-06      2930       2940       2950      2910  14,82M      0,00%
# 21 2024-05-03      2930       2910       2950      2890  15,12M      1,38%
# 22 2024-05-02      2890       2760       2920      2750  45,40M     -4,62%
# 23 2024-04-30      3030       3000       3030      2980  14,32M      1,00%
# 24 2024-04-29      3000       2900       3000      2860  11,27M      4,17%
# 25 2024-04-26      2880       2900       2940      2880  11,56M     -0,35%
# 26 2024-04-25      2890       2960       2960      2870  23,58M     -2,36%
# 27 2024-04-24      2960       3080       3100      2870  31,02M     -3,27%
# 28 2024-04-23      3060       3080       3090      3050   8,42M     -0,65%
# 29 2024-04-22      3080       3140       3150      3060  19,62M     -1,91%
# 30 2024-04-19      3140       3130       3150      3090  22,92M      0,32%
# 31 2024-04-18      3130       3100       3130      3030  26,81M      1,29%
# 32 2024-04-17      3090       3120       3160      3060  36,78M     -0,32%
# 33 2024-04-16      3100       2940       3130      2930  58,08M      5,80%

# %%
dataset_new = dataset_new.sort_values(by='Tanggal',
                              ascending = True,
                              ignore_index = True)
dataset_new
# Out:
#       Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah     Vol Perubahan%
# 0  2024-04-16      3100       2940       3130      2930  58,08M      5,80%
# 1  2024-04-17      3090       3120       3160      3060  36,78M     -0,32%
# 2  2024-04-18      3130       3100       3130      3030  26,81M      1,29%
# 3  2024-04-19      3140       3130       3150      3090  22,92M      0,32%
# 4  2024-04-22      3080       3140       3150      3060  19,62M     -1,91%
# 5  2024-04-23      3060       3080       3090      3050   8,42M     -0,65%
# 6  2024-04-24      2960       3080       3100      2870  31,02M     -3,27%
# 7  2024-04-25      2890       2960       2960      2870  23,58M     -2,36%
# 8  2024-04-26      2880       2900       2940      2880  11,56M     -0,35%
# 9  2024-04-29      3000       2900       3000      2860  11,27M      4,17%
# 10 2024-04-30      3030       3000       3030      2980  14,32M      1,00%
# 11 2024-05-02      2890       2760       2920      2750  45,40M     -4,62%
# 12 2024-05-03      2930       2910       2950      2890  15,12M      1,38%
# 13 2024-05-06      2930       2940       2950      2910  14,82M      0,00%
# 14 2024-05-07      2880       2940       2950      2870  19,84M     -1,71%
# 15 2024-05-08      2930       2900       3020      2790  89,51M      1,74%
# 16 2024-05-13      2930       2950       2970      2910  20,60M      0,00%
# 17 2024-05-14      2920       2940       2960      2920  22,33M     -0,34%
# 18 2024-05-15      2910       2940       2950      2900  16,34M     -0,34%
# 19 2024-05-16      2930       2920       2930      2900  21,54M      0,69%
# 20 2024-05-17      2920       2930       2950      2910  30,77M     -0,34%
# 21 2024-05-20      2930       2930       2960      2910  72,08M      0,34%
# 22 2024-05-21      2570       2550       2640      2530  63,14M    -12,29%
# 23 2024-05-22      2590       2570       2600      2570  18,23M      0,78%
# 24 2024-05-27      2520       2600       2600      2520  21,41M     -2,70%
# 25 2024-05-28      2510       2540       2560      2510  11,91M     -0,40%
# 26 2024-05-29      2470       2520       2530      2460  14,74M     -1,59%
# 27 2024-05-30      2490       2470       2500      2420   9,64M      0,81%
# 28 2024-05-31      2490       2500       2520      2490  15,71M      0,00%
# 29 2024-06-03      2580       2500       2590      2500  16,72M      3,61%
# 30 2024-06-04      2570       2590       2590      2560  11,33M     -0,39%
# 31 2024-06-05      2530       2570       2580      2500  10,33M     -1,56%
# 32 2024-06-06      2510       2530       2540      2500   4,89M     -0,79%
# 33 2024-06-07      2530       2520       2550      2510   7,71M      0,80%

# %%
dataset_new = dataset_new.replace(to_replace = ',',
                          value = '.',
                          regex = True)
dataset_new
# Out:
#       Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah     Vol Perubahan%
# 0  2024-04-16      3100       2940       3130      2930  58.08M      5.80%
# 1  2024-04-17      3090       3120       3160      3060  36.78M     -0.32%
# 2  2024-04-18      3130       3100       3130      3030  26.81M      1.29%
# 3  2024-04-19      3140       3130       3150      3090  22.92M      0.32%
# 4  2024-04-22      3080       3140       3150      3060  19.62M     -1.91%
# 5  2024-04-23      3060       3080       3090      3050   8.42M     -0.65%
# 6  2024-04-24      2960       3080       3100      2870  31.02M     -3.27%
# 7  2024-04-25      2890       2960       2960      2870  23.58M     -2.36%
# 8  2024-04-26      2880       2900       2940      2880  11.56M     -0.35%
# 9  2024-04-29      3000       2900       3000      2860  11.27M      4.17%
# 10 2024-04-30      3030       3000       3030      2980  14.32M      1.00%
# 11 2024-05-02      2890       2760       2920      2750  45.40M     -4.62%
# 12 2024-05-03      2930       2910       2950      2890  15.12M      1.38%
# 13 2024-05-06      2930       2940       2950      2910  14.82M      0.00%
# 14 2024-05-07      2880       2940       2950      2870  19.84M     -1.71%
# 15 2024-05-08      2930       2900       3020      2790  89.51M      1.74%
# 16 2024-05-13      2930       2950       2970      2910  20.60M      0.00%
# 17 2024-05-14      2920       2940       2960      2920  22.33M     -0.34%
# 18 2024-05-15      2910       2940       2950      2900  16.34M     -0.34%
# 19 2024-05-16      2930       2920       2930      2900  21.54M      0.69%
# 20 2024-05-17      2920       2930       2950      2910  30.77M     -0.34%
# 21 2024-05-20      2930       2930       2960      2910  72.08M      0.34%
# 22 2024-05-21      2570       2550       2640      2530  63.14M    -12.29%
# 23 2024-05-22      2590       2570       2600      2570  18.23M      0.78%
# 24 2024-05-27      2520       2600       2600      2520  21.41M     -2.70%
# 25 2024-05-28      2510       2540       2560      2510  11.91M     -0.40%
# 26 2024-05-29      2470       2520       2530      2460  14.74M     -1.59%
# 27 2024-05-30      2490       2470       2500      2420   9.64M      0.81%
# 28 2024-05-31      2490       2500       2520      2490  15.71M      0.00%
# 29 2024-06-03      2580       2500       2590      2500  16.72M      3.61%
# 30 2024-06-04      2570       2590       2590      2560  11.33M     -0.39%
# 31 2024-06-05      2530       2570       2580      2500  10.33M     -1.56%
# 32 2024-06-06      2510       2530       2540      2500   4.89M     -0.79%
# 33 2024-06-07      2530       2520       2550      2510   7.71M      0.80%

# %%
def replace_value(value):
    if 'K' in value:
        return str(float(value.replace('K', '')) * 1000)
    elif 'M' in value:
        return str(float(value.replace('M', '')) * 1000000)
    elif 'B' in value:
        return str(float(value.replace('B', '')) * 1000000000)
    return value

dataset_new['Vol'] = dataset_new['Vol'].apply(replace_value)

dataset_new
# Out:
#       Tanggal  Terakhir  Pembukaan  Tertinggi  Terendah                 Vol  \
# 0  2024-04-16      3100       2940       3130      2930          58080000.0
# 1  2024-04-17      3090       3120       3160      3060          36780000.0
# 2  2024-04-18      3130       3100       3130      3030          26810000.0
# 3  2024-04-19      3140       3130       3150      3090          22920000.0
# 4  2024-04-22      3080       3140       3150      3060          19620000.0
# 5  2024-04-23      3060       3080       3090      3050           8420000.0
# 6  2024-04-24      2960       3080       3100      2870          31020000.0
# 7  2024-04-25      2890       2960       2960      2870          23580000.0
# 8  2024-04-26      2880       2900       2940      2880          11560000.0
# 9  2024-04-29      3000       2900       3000      2860          11270000.0
# 10 2024-04-30      3030       3000       3030      2980          14320000.0
# 11 2024-05-02      2890       2760       2920      2750          45400000.0
# 12 2024-05-03      2930       2910       2950      2890          15120000.0
# 13 2024-05-06      2930       2940       2950      2910          14820000.0
# 14 2024-05-07      2880       2940       2950      2870          19840000.0
# 15 2024-05-08      2930       2900       3020      2790          89510000.0
# 16 2024-05-13      2930       2950       2970      2910          20600000.0
# 17 2024-05-14      2920       2940       2960      2920          22330000.0
# 18 2024-05-15      2910       2940       2950      2900          16340000.0
# 19 2024-05-16      2930       2920       2930      2900          21540000.0
# 20 2024-05-17      2920       2930       2950      2910          30770000.0
# 21 2024-05-20      2930       2930       2960      2910          72080000.0
# 22 2024-05-21      2570       2550       2640      2530          63140000.0
# 23 2024-05-22      2590       2570       2600      2570          18230000.0
# 24 2024-05-27      2520       2600       2600      2520          21410000.0
# 25 2024-05-28      2510       2540       2560      2510          11910000.0
# 26 2024-05-29      2470       2520       2530      2460          14740000.0
# 27 2024-05-30      2490       2470       2500      2420           9640000.0
# 28 2024-05-31      2490       2500       2520      2490          15710000.0
# 29 2024-06-03      2580       2500       2590      2500  16719999.999999998
# 30 2024-06-04      2570       2590       2590      2560          11330000.0
# 31 2024-06-05      2530       2570       2580      2500          10330000.0
# 32 2024-06-06      2510       2530       2540      2500           4890000.0
# 33 2024-06-07      2530       2520       2550      2510           7710000.0
#
#    Perubahan%
# 0       5.80%
# 1      -0.32%
# 2       1.29%
# 3       0.32%
# 4      -1.91%
# 5      -0.65%
# 6      -3.27%
# 7      -2.36%
# 8      -0.35%
# 9       4.17%
# 10      1.00%
# 11     -4.62%
# 12      1.38%
# 13      0.00%
# 14     -1.71%
# 15      1.74%
# 16      0.00%
# 17     -0.34%
# 18     -0.34%
# 19      0.69%
# 20     -0.34%
# 21      0.34%
# 22    -12.29%
# 23      0.78%
# 24     -2.70%
# 25     -0.40%
# 26     -1.59%
# 27      0.81%
# 28      0.00%
# 29      3.61%
# 30     -0.39%
# 31     -1.56%
# 32     -0.79%
# 33      0.80%

# %%
dataset_new = dataset_new.astype({'Terakhir': 'float32'})
dataset_new.dtypes
# Out:
# Tanggal       datetime64[ns]
# Terakhir             float32
# Pembukaan              int64
# Tertinggi              int64
# Terendah               int64
# Vol                   object
# Perubahan%            object
# dtype: object

# %%
dataset_new = dataset_new.astype({'Vol': 'float32'})
dataset_new.dtypes
# Out:
# Tanggal       datetime64[ns]
# Terakhir             float32
# Pembukaan              int64
# Tertinggi              int64
# Terendah               int64
# Vol                  float32
# Perubahan%            object
# dtype: object

# %%
plt.figure(figsize=(60,10))

plt.subplot(1,2,1)
plt.plot(dataset_new['Tanggal'], dataset_new['Terakhir'])
plt.title('Harga Penutupan Saham PTBA/Hari', fontsize = 20)

plt.figure(figsize=(60,10))

plt.subplot(1,2,1)
plt.plot(dataset_new['Tanggal'], dataset_new['Vol'], 'g')
plt.title('Volume Transaksi Saham PTBA/Hari', fontsize = 20)

plt.show()

# %%
data_use_new = np.column_stack((dataset_new['Terakhir'], dataset_new['Vol']))
tanggal_data_new = pd.DataFrame({'Tanggal' : dataset_new['Tanggal']})

print(data_use_new)
print(tanggal_data_new)
# Out:
# [[3.100e+03 5.808e+07]
#  [3.090e+03 3.678e+07]
#  [3.130e+03 2.681e+07]
#  [3.140e+03 2.292e+07]
#  [3.080e+03 1.962e+07]
#  [3.060e+03 8.420e+06]
#  [2.960e+03 3.102e+07]
#  [2.890e+03 2.358e+07]
#  [2.880e+03 1.156e+07]
#  [3.000e+03 1.127e+07]
#  [3.030e+03 1.432e+07]
#  [2.890e+03 4.540e+07]
#  [2.930e+03 1.512e+07]
#  [2.930e+03 1.482e+07]
#  [2.880e+03 1.984e+07]
#  [2.930e+03 8.951e+07]
#  [2.930e+03 2.060e+07]
#  [2.920e+03 2.233e+07]
#  [2.910e+03 1.634e+07]
#  [2.930e+03 2.154e+07]
#  [2.920e+03 3.077e+07]
#  [2.930e+03 7.208e+07]
#  [2.570e+03 6.314e+07]
#  [2.590e+03 1.823e+07]
#  [2.520e+03 2.141e+07]
#  [2.510e+03 1.191e+07]
#  [2.470e+03 1.474e+07]
#  [2.490e+03 9.640e+06]
#  [2.490e+03 1.571e+07]
#  [2.580e+03 1.672e+07]
#  [2.570e+03 1.133e+07]
#  [2.530e+03 1.033e+07]
#  [2.510e+03 4.890e+06]
#  [2.530e+03 7.710e+06]]
#       Tanggal
# 0  2024-04-16
# 1  2024-04-17
# 2  2024-04-18
# 3  2024-04-19
# 4  2024-04-22
# 5  2024-04-23
# 6  2024-04-24
# 7  2024-04-25
# 8  2024-04-26
# 9  2024-04-29
# 10 2024-04-30
# 11 2024-05-02
# 12 2024-05-03
# 13 2024-05-06
# 14 2024-05-07
# 15 2024-05-08
# 16 2024-05-13
# 17 2024-05-14
# 18 2024-05-15
# 19 2024-05-16
# 20 2024-05-17
# 21 2024-05-20
# 22 2024-05-21
# 23 2024-05-22
# 24 2024-05-27
# 25 2024-05-28
# 26 2024-05-29
# 27 2024-05-30
# 28 2024-05-31
# 29 2024-06-03
# 30 2024-06-04
# 31 2024-06-05
# 32 2024-06-06
# 33 2024-06-07

# %%
scaled_data_new = scaler.fit_transform(data_use_new)

# %%
print(scaled_data_new)
# Out:
# [[0.94029856 0.6285748 ]
#  [0.9253731  0.37686127]
#  [0.9850745  0.25904042]
#  [1.         0.2130702 ]
#  [0.9104476  0.17407233]
#  [0.8805971  0.04171591]
#  [0.73134327 0.30879226]
#  [0.6268654  0.22086976]
#  [0.6119404  0.07882297]
#  [0.7910447  0.07539588]
#  [0.8358207  0.11143938]
#  [0.6268654  0.47872844]
#  [0.6865668  0.1208934 ]
#  [0.6865668  0.11734813]
#  [0.6119404  0.17667218]
#  [0.6865668  1.        ]
#  [0.6865668  0.18565351]
#  [0.6716418  0.20609786]
#  [0.65671635 0.1353108 ]
#  [0.6865668  0.19676198]
#  [0.6716418  0.30583787]
#  [0.6865668  0.7940203 ]
#  [0.1492536  0.68837154]
#  [0.17910433 0.15764594]
#  [0.07462668 0.1952257 ]
#  [0.05970144 0.0829591 ]
#  [0.         0.11640273]
#  [0.02985072 0.0561333 ]
#  [0.02985072 0.12786575]
#  [0.16417909 0.13980146]
#  [0.1492536  0.07610494]
#  [0.08955216 0.06428739]
#  [0.05970144 0.        ]
#  [0.08955216 0.03332545]]

# %%
harga_new = scaled_data_new[:, 0]
volume_new = scaled_data_new[:, 1]
print(harga_new)
print(volume_new)
# Out:
# [0.94029856 0.9253731  0.9850745  1.         0.9104476  0.8805971
#  0.73134327 0.6268654  0.6119404  0.7910447  0.8358207  0.6268654
#  0.6865668  0.6865668  0.6119404  0.6865668  0.6865668  0.6716418
#  0.65671635 0.6865668  0.6716418  0.6865668  0.1492536  0.17910433
#  0.07462668 0.05970144 0.         0.02985072 0.02985072 0.16417909
#  0.1492536  0.08955216 0.05970144 0.08955216]
# [0.6285748  0.37686127 0.25904042 0.2130702  0.17407233 0.04171591
#  0.30879226 0.22086976 0.07882297 0.07539588 0.11143938 0.47872844
#  0.1208934  0.11734813 0.17667218 1.         0.18565351 0.20609786
#  0.1353108  0.19676198 0.30583787 0.7940203  0.68837154 0.15764594
#  0.1952257  0.0829591  0.11640273 0.0561333  0.12786575 0.13980146
#  0.07610494 0.06428739 0.         0.03332545]

# %%
seq_length = 10  # Panjang urutan yang digunakan untuk pelatihan
predict_length = 20  # Prediksi 1 Bulan ke depan (20 hari perdagangan)

x_new = []

for i in range(len(scaled_data_new) - seq_length):
    x_new.append(scaled_data_new[i:i + seq_length])

x_new = np.array(x_new)

# Convert to PyTorch tensors
x_new_tensor = torch.tensor(x_new, dtype=torch.float32)

# %%
model.eval()
with torch.no_grad():
    predictions_new = model(x_new_tensor)

# Konversi prediksi dari tensor ke numpy array
predictions_new = predictions_new.numpy()

# %%
print(predictions_new)
# Out:
# [[ 0.83798295]
#  [ 0.8391656 ]
#  [ 0.6208676 ]
#  [ 0.7446178 ]
#  [ 0.69611067]
#  [ 0.6155299 ]
#  [ 0.6768073 ]
#  [ 0.72333765]
#  [ 0.69132924]
#  [ 0.6821344 ]
#  [ 0.7093017 ]
#  [ 0.6838872 ]
#  [ 0.68437076]
#  [-0.01491652]
#  [ 0.11285396]
#  [ 0.00852621]
#  [ 0.0384733 ]
#  [ 0.02171213]
#  [ 0.02048108]
#  [ 0.02160345]
#  [ 0.08041983]
#  [ 0.12577221]
#  [ 0.11369582]
#  [ 0.07814278]]

# %%
# Ambil hanya kolom harga dari prediksi (kolom pertama)
predicted_prices_new = scaler.inverse_transform(
    np.concatenate([predictions_new, np.zeros((predictions_new.shape[0], 1))], axis=1)
)[:, 0]

# %%
print(predicted_prices_new)
# Out:
# [3031.44864961 3032.24104209 2885.98137121 2968.89401112 2936.39421821
#  2882.40510208 2923.46095274 2954.63629768 2933.19066348 2927.03011341
#  2945.23221784 2928.20448524 2928.5284788  2460.00600462 2545.61222788
#  2475.71263879 2495.77718704 2484.54720151 2483.72239669 2484.47438482
#  2523.88136214 2554.26745449 2546.1762714  2522.35574104]

# %%
df_new = pd.DataFrame(dataset_new, columns=['Tanggal', 'Terakhir', 'Vol'])

# %%
df_new
# Out:
#       Tanggal  Terakhir         Vol
# 0  2024-04-16    3100.0  58080000.0
# 1  2024-04-17    3090.0  36780000.0
# 2  2024-04-18    3130.0  26810000.0
# 3  2024-04-19    3140.0  22920000.0
# 4  2024-04-22    3080.0  19620000.0
# 5  2024-04-23    3060.0   8420000.0
# 6  2024-04-24    2960.0  31020000.0
# 7  2024-04-25    2890.0  23580000.0
# 8  2024-04-26    2880.0  11560000.0
# 9  2024-04-29    3000.0  11270000.0
# 10 2024-04-30    3030.0  14320000.0
# 11 2024-05-02    2890.0  45400000.0
# 12 2024-05-03    2930.0  15120000.0
# 13 2024-05-06    2930.0  14820000.0
# 14 2024-05-07    2880.0  19840000.0
# 15 2024-05-08    2930.0  89510000.0
# 16 2024-05-13    2930.0  20600000.0
# 17 2024-05-14    2920.0  22330000.0
# 18 2024-05-15    2910.0  16340000.0
# 19 2024-05-16    2930.0  21540000.0
# 20 2024-05-17    2920.0  30770000.0
# 21 2024-05-20    2930.0  72080000.0
# 22 2024-05-21    2570.0  63140000.0
# 23 2024-05-22    2590.0  18230000.0
# 24 2024-05-27    2520.0  21410000.0
# 25 2024-05-28    2510.0  11910000.0
# 26 2024-05-29    2470.0  14740000.0
# 27 2024-05-30    2490.0   9640000.0
# 28 2024-05-31    2490.0  15710000.0
# 29 2024-06-03    2580.0  16720000.0
# 30 2024-06-04    2570.0  11330000.0
# 31 2024-06-05    2530.0  10330000.0
# 32 2024-06-06    2510.0   4890000.0
# 33 2024-06-07    2530.0   7710000.0

# %%
# Buat DataFrame untuk prediksi dimulai dari tanggal 10
# Ambil tanggal terakhir dari data asli
last_date = pd.to_datetime(df_new['Tanggal'].iloc[-1])

# Tentukan tanggal mulai prediksi
start_date = last_date + pd.Timedelta(days=3)  # Dari tanggal 7 ke tanggal 10

# Buat range tanggal untuk prediksi
pred_dates = pd.date_range(start=start_date, periods=predict_length)

# %%
# Buat DataFrame untuk prediksi
pred_df = pd.DataFrame({'Tanggal': pred_dates, 'Harga_Terprediksi': predicted_prices_new[-predict_length:]})

# Gabungkan dengan DataFrame asli
result_df_new = pd.concat([df_new, pred_df[['Tanggal', 'Harga_Terprediksi']]], axis=0)

# %%
# Gabungkan dengan DataFrame asli
result_df_new = pd.concat([df_new, pred_df[['Tanggal', 'Harga_Terprediksi']]], axis=0)

print(result_df_new)
# Out:
#       Tanggal  Terakhir         Vol  Harga_Terprediksi
# 0  2024-04-16    3100.0  58080000.0                NaN
# 1  2024-04-17    3090.0  36780000.0                NaN
# 2  2024-04-18    3130.0  26810000.0                NaN
# 3  2024-04-19    3140.0  22920000.0                NaN
# 4  2024-04-22    3080.0  19620000.0                NaN
# 5  2024-04-23    3060.0   8420000.0                NaN
# 6  2024-04-24    2960.0  31020000.0                NaN
# 7  2024-04-25    2890.0  23580000.0                NaN
# 8  2024-04-26    2880.0  11560000.0                NaN
# 9  2024-04-29    3000.0  11270000.0                NaN
# 10 2024-04-30    3030.0  14320000.0                NaN
# 11 2024-05-02    2890.0  45400000.0                NaN
# 12 2024-05-03    2930.0  15120000.0                NaN
# 13 2024-05-06    2930.0  14820000.0                NaN
# 14 2024-05-07    2880.0  19840000.0                NaN
# 15 2024-05-08    2930.0  89510000.0                NaN
# 16 2024-05-13    2930.0  20600000.0                NaN
# 17 2024-05-14    2920.0  22330000.0                NaN
# 18 2024-05-15    2910.0  16340000.0                NaN
# 19 2024-05-16    2930.0  21540000.0                NaN
# 20 2024-05-17    2920.0  30770000.0                NaN
# 21 2024-05-20    2930.0  72080000.0                NaN
# 22 2024-05-21    2570.0  63140000.0                NaN
# 23 2024-05-22    2590.0  18230000.0                NaN
# 24 2024-05-27    2520.0  21410000.0                NaN
# 25 2024-05-28    2510.0  11910000.0                NaN
# 26 2024-05-29    2470.0  14740000.0                NaN
# 27 2024-05-30    2490.0   9640000.0                NaN
# 28 2024-05-31    2490.0  15710000.0                NaN
# 29 2024-06-03    2580.0  16720000.0                NaN
# 30 2024-06-04    2570.0  11330000.0                NaN
# 31 2024-06-05    2530.0  10330000.0                NaN
# 32 2024-06-06    2510.0   4890000.0                NaN
# 33 2024-06-07    2530.0   7710000.0                NaN
# 0  2024-06-10       NaN         NaN        2936.394218
# 1  2024-06-11       NaN         NaN        2882.405102
# 2  2024-06-12       NaN         NaN        2923.460953
# 3  2024-06-13       NaN         NaN        2954.636298
# 4  2024-06-14       NaN         NaN        2933.190663
# 5  2024-06-15       NaN         NaN        2927.030113
# 6  2024-06-16       NaN         NaN        2945.232218
# 7  2024-06-17       NaN         NaN        2928.204485
# 8  2024-06-18       NaN         NaN        2928.528479
# 9  2024-06-19       NaN         NaN        2460.006005
# 10 2024-06-20       NaN         NaN        2545.612228
# 11 2024-06-21       NaN         NaN        2475.712639
# 12 2024-06-22       NaN         NaN        2495.777187
# 13 2024-06-23       NaN         NaN        2484.547202
# 14 2024-06-24       NaN         NaN        2483.722397
# 15 2024-06-25       NaN         NaN        2484.474385
# 16 2024-06-26       NaN         NaN        2523.881362
# 17 2024-06-27       NaN         NaN        2554.267454
# 18 2024-06-28       NaN         NaN        2546.176271
# 19 2024-06-29       NaN         NaN        2522.355741

# %%
# Plotting
plt.figure(figsize=(14, 7))

# Plot data asli
plt.plot(result_df_new['Tanggal'][:len(df_new)], df_new['Terakhir'], label='Actual Price', color='blue')

# Plot data prediksi
plt.plot(pred_df['Tanggal'], pred_df['Harga_Terprediksi'], label='Predicted Price', color='red', linestyle='--', linewidth=2)

# Konfigurasi grafik
plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# Menampilkan grafik
plt.show()

# %%
result_df_new.to_csv('Harga Terprediksi PTBA.csv', index=False)
